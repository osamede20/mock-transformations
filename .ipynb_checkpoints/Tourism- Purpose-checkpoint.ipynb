# %% [markdown]
# # Tourism
#
# -----
#
# ### Requirements
#
# Extract the data from tab 2 and tab 4.
#
# #### Observations & Dimensions
#
# For `observations` we want the `purpose` data, we **dont** want the `all visits`.
#
#
# The required dimensions are:
#
# * **Geography** - it's all UK level data (the code for UK is "K02000001")
# * **Time** - in the format MMM YYYY
# * **Purpose** - one of Holiday, Business, Visiting friends or relatives, Miscellaneous
# * **Direction of Travel** - either "overseas visits to the uk", or "uk visits abroad"
# * **Units** - constant value of '1000'
#
# -----
# Notes:
#
# * We dont want the data markings against 2019 dates
# * We don't want the ad hoc summary data at the bottom , "latest three months.." etc

# %%
from databaker.framework import *
import pandas as pd

tabs2and4 = ['Table 2', 'Table 4']
tabs = loadxlstabs("./sources/tourism.xls", tabs2and4) # load tabs
# Out:
# Loading ./sources/tourism.xls which has size 180736 bytes
# Table names: ['Table 2', 'Table 4']

# %%
len(tabs)
# Out:
# 2

# %%
tidied_sheets = [] # datacube for the two cubes

for tab in tabs:
    bottomblock = tab.filter("Latest three months").expand(DOWN).expand(RIGHT).is_not_blank()
    
    observations = tab.excel_ref("G7").expand(DOWN).expand(RIGHT).is_not_blank() - bottomblock
    
    geography = "K02000001"
    month = tab.excel_ref("B7").expand(DOWN).is_not_blank() - bottomblock
    year = tab.excel_ref("A7").expand(DOWN).is_not_blank() - bottomblock
    purpose = tab.excel_ref("G4").expand(RIGHT).is_not_blank()
    
    direction = tab.excel_ref("B1")
    units = "thousands" #1000
    #observations = month.waffle(purpose)
    
    dimensions = [
        HDimConst("Geography", geography),
        HDimConst("Units", units),
        HDimConst("Direction", direction.value),
        HDim(month, "Month", DIRECTLY, LEFT),
        HDim(year, "Year", CLOSEST, UP),
        HDim(purpose, 'Purpose', DIRECTLY, ABOVE)
            ]
    cs = ConversionSegment(tab, dimensions, observations) # < --- processing
    tidy_sheet = cs.topandas() #dataframe
    tidied_sheets.append(tidy_sheet) # <-- adding result of processing this tab to our list

# %%
datacube = pd.concat(tidied_sheets)

# %%
datacube
# Out:
#              OBS  Geography      Units  \
# 0     662.512925  K02000001  thousands
# 1     688.776441  K02000001  thousands
# 2     899.146350  K02000001  thousands
# 3     168.449570  K02000001  thousands
# 4     639.824439  K02000001  thousands
# ..           ...        ...        ...
# 211   120.000000  K02000001  thousands
# 212  4850.000000  K02000001  thousands
# 213   610.000000  K02000001  thousands
# 214  1240.000000  K02000001  thousands
# 215   140.000000  K02000001  thousands
#
#                                              Direction  Month    Year  \
# 0    Purpose of overseas residents' visits to the U...    Jan  2015.0
# 1    Purpose of overseas residents' visits to the U...    Jan  2015.0
# 2    Purpose of overseas residents' visits to the U...    Jan  2015.0
# 3    Purpose of overseas residents' visits to the U...    Jan  2015.0
# 4    Purpose of overseas residents' visits to the U...    Feb  2015.0
# ..                                                 ...    ...     ...
# 211    Purpose of UK residents' visits abroad by month   May¹  2019.0
# 212    Purpose of UK residents' visits abroad by month  June¹  2019.0
# 213    Purpose of UK residents' visits abroad by month  June¹  2019.0
# 214    Purpose of UK residents' visits abroad by month  June¹  2019.0
# 215    Purpose of UK residents' visits abroad by month  June¹  2019.0
#
#                            Purpose
# 0                          Holiday
# 1                         Business
# 2    Visiting friends or relatives
# 3                    Miscellaneous
# 4                          Holiday
# ..                             ...
# 211                  Miscellaneous
# 212                        Holiday
# 213                       Business
# 214  Visiting friends or relatives
# 215                  Miscellaneous
#
# [432 rows x 7 columns]

# %%
datacube["Direction"]\
.replace({"Purpose of overseas residents\' visits to the UK by month" : "Overseas visits to the UK", 
"Purpose of UK residents\' visits abroad by month" : "UK visits abroad"}, inplace=True)

# %%
datacube["Month"] = datacube["Month"].str[:3]
datacube["Year"] = datacube["Year"].astype(float).astype(int).astype(str)
datacube["Time"] = datacube["Month"] + " " + datacube["Year"]
datacube.drop(columns = ["Month", "Year"], inplace=True)

# %%
datacube
# Out:
#              OBS  Geography      Units                  Direction  \
# 0     662.512925  K02000001  thousands  Overseas visits to the UK
# 1     688.776441  K02000001  thousands  Overseas visits to the UK
# 2     899.146350  K02000001  thousands  Overseas visits to the UK
# 3     168.449570  K02000001  thousands  Overseas visits to the UK
# 4     639.824439  K02000001  thousands  Overseas visits to the UK
# ..           ...        ...        ...                        ...
# 211   120.000000  K02000001  thousands           UK visits abroad
# 212  4850.000000  K02000001  thousands           UK visits abroad
# 213   610.000000  K02000001  thousands           UK visits abroad
# 214  1240.000000  K02000001  thousands           UK visits abroad
# 215   140.000000  K02000001  thousands           UK visits abroad
#
#                            Purpose      Time
# 0                          Holiday  Jan 2015
# 1                         Business  Jan 2015
# 2    Visiting friends or relatives  Jan 2015
# 3                    Miscellaneous  Jan 2015
# 4                          Holiday  Feb 2015
# ..                             ...       ...
# 211                  Miscellaneous  May 2019
# 212                        Holiday  Jun 2019
# 213                       Business  Jun 2019
# 214  Visiting friends or relatives  Jun 2019
# 215                  Miscellaneous  Jun 2019
#
# [432 rows x 6 columns]
